# %%
import os

import csv

csvpath = 'qb_stats_master.csv'

# %%
rank = []
name = []
yards = []
tds = []
ints = []
td_int_ratio = []
completions = []
attempts = []
comp_per = []
passer_rating = []
ypg = []
games_played = []
seasons_played = []
number_teams = []

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)

    for row in csvreader:
        rank.append(int(row[0]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)

    for row in csvreader:
            name.append((row[1]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        yards.append((row[2]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        tds.append((row[3]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        ints.append((row[4]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        td_int_ratio.append((row[5]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        completions.append((row[6]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        attempts.append((row[7]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        comp_per.append((row[8]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        passer_rating.append((row[9]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        ypg.append((row[10]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        games_played.append((row[11]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        seasons_played.append((row[12]))

# %%
with open(csvpath, newline='') as csvfile:

    csvreader = csv.reader(csvfile,delimiter=',')
    if csv.Sniffer().has_header:
        next(csvreader)
        
    for row in csvreader:
        number_teams.append((row[13]))

# %%
stuff = list(zip(*[rank,name,yards,tds,ints,td_int_ratio,completions,attempts,comp_per,passer_rating,ypg,games_played,seasons_played,number_teams]))

# %%
qb_data = {}


qb_data['Rank'] = [x[0] for x in stuff]

stuff
# Out:
# [(100,
#   'Jeff George',
#   ' 27,602 ',
#   '154',
#   '113',
#   '1.36',
#   ' 2,298 ',
#   ' 3,967 ',
#   '57.93%',
#   '80.40',
#   '210.70',
#   '131',
#   '11',
#   '5TM'),
#  (99,
#   'Lynn Dickey',
#   ' 23,322 ',
#   '141',
#   '179',
#   '0.79',
#   ' 1,747 ',
#   ' 3,125 ',
#   '55.90%',
#   '70.90',
#   '153.40',
#   '152',
#   '14',
#   '2TM'),
#  (98,
#   'Jeff Blake',
#   ' 21,711 ',
#   '134',
#   '99',
#   '1.35',
#   ' 1,827 ',
#   ' 3,241 ',
#   '56.37%',
#   '78.00',
#   '182.40',
#   '119',
#   '13',
#   '7TM'),
#  (97,
#   'Matt Schaub',
#   ' 25,412 ',
#   '135',
#   '91',
#   '1.48',
#   ' 2,143 ',
#   ' 3,339 ',
#   '64.18%',
#   '89.40',
#   '167.20',
#   '152',
#   '15',
#   '4TM'),
#  (96,
#   'Babe Parilli',
#   ' 22,681 ',
#   '178',
#   '220',
#   '0.81',
#   ' 1,552 ',
#   ' 3,330 ',
#   '46.61%',
#   '59.60',
#   '120.00',
#   '189',
#   '17',
#   '5TM'),
#  (95,
#   'Andrew Luck',
#   ' 23,671 ',
#   '171',
#   '83',
#   '2.06',
#   ' 2,000 ',
# ...

# %%
column_names = ['Rank','Name','Passing_Yds','TDs','Int','TD_INT_Ratio','Completions','Attempts','Completion_Percentage','Passser_Ratings','YPG','Game_Played','Seasons_Played','Number_of_Teams']

my_dict = {}

counter = 0

for x in stuff:
    for i in column_names:
        my_dict[i] = x[counter]
        counter += 1
        if counter == len(column_names):
            counter = 0
        
my_dict
# Out:
# {'Rank': 1,
#  'Name': 'Tom Brady',
#  'Passing_Yds': ' 73,266 ',
#  'TDs': '531',
#  'Int': '176',
#  'TD_INT_Ratio': '3.02',
#  'Completions': ' 6,260 ',
#  'Attempts': ' 9,777 ',
#  'Completion_Percentage': '64.03%',
#  'Passser_Ratings': '97.30',
#  'YPG': '262.60',
#  'Game_Played': '279',
#  'Seasons_Played': '19',
#  'Number_of_Teams': 'nwe'}

# %%
rank_dict = {}
yds_dict = {}
name_dict = {}
tds_dict = {}
ints_dict = {}
ratio_dict = {}
comp_dict = {}
PR_dict = {}
YPG_dict = {}
GP_dict = {}
SP_dict = {}
NT_dict = {}
attempts_dict = {}
comp_per_dict = {}


rank_dict['Rank'] = rank
name_dict['Full_Name'] = name
yds_dict['Passing_Yards'] = yards
tds_dict['Touchdowns'] = tds
ints_dict['Interceptions'] = ints
ratio_dict['TD_INT_Ratio'] = td_int_ratio
comp_dict['Completions'] = completions
attempts_dict['Attempts'] = attempts
comp_per_dict['Comp%'] = comp_per
PR_dict['Passer_Rating'] = passer_rating
YPG_dict['Yards_Per_Game'] = ypg
GP_dict['Games_Played'] = games_played
SP_dict['Seasons_Played'] = seasons_played
NT_dict['Num_of_Teams'] = number_teams

# %%
stuff2 = (zip(*[rank_dict,yds_dict,name_dict,tds_dict,ints_dict,ratio_dict,comp_dict,PR_dict,YPG_dict,GP_dict,SP_dict,NT_dict,attempts_dict,comp_per_dict]))

# %%
stuff2

# %%
import pymongo

# Setup connection to mongodb
conn = "mongodb://localhost:27017"
client = pymongo.MongoClient(conn)

# Select database and collection to use
db = client.nfl
collection = db.football

db.collection.insert_many([rank_dict,yds_dict,name_dict,tds_dict,ints_dict,ratio_dict,comp_dict,PR_dict,YPG_dict,GP_dict,SP_dict,NT_dict,attempts_dict,comp_per_dict])
